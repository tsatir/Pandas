# %% [markdown]
# <a href="https://colab.research.google.com/github/tsatir/Thinkful-Data_Science/blob/master/SVM_recipes_with_rating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What am I doing?**
#
# Transform this regression problem into a binary classifier and clean up the feature set. You can choose whether or not to include nutritional information, but try to cut your feature set down to the 30 most valuable features.
#
# **Dataset**
# https://www.kaggle.com/hugodarwood/epirecipes
#
# Over 20k recipes listed by recipe rating, nutritional information and assigned category (sparse).

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
raw_data = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/epi_r.csv')

# %%
raw_data.describe()
# Out:
#              rating      calories  ...    snack week        turkey
# count  20052.000000  1.593500e+04  ...  20052.000000  20052.000000
# mean       3.714467  6.322958e+03  ...      0.000948      0.022741
# std        1.340829  3.590460e+05  ...      0.030768      0.149080
# min        0.000000  0.000000e+00  ...      0.000000      0.000000
# 25%        3.750000  1.980000e+02  ...      0.000000      0.000000
# 50%        4.375000  3.310000e+02  ...      0.000000      0.000000
# 75%        4.375000  5.860000e+02  ...      0.000000      0.000000
# max        5.000000  3.011122e+07  ...      1.000000      1.000000
#
# [8 rows x 679 columns]

# %%
raw_data.shape
# Out:
# (20052, 680)

# %% [markdown]
# **Missing Values**

# %%
drop_mis_valu = []
for i in raw_data.columns:
  x = raw_data[i].isnull().sum()
  if x > 0:
    drop_mis_valu.append(i)

# %%
raw_data.drop(drop_mis_valu,1, inplace=True)

# %%
raw_data[['title','rating']].nunique()
# Out:
# title     17736
# rating        8
# dtype: int64

# %% [markdown]
# **Adding a new class as target, a rating is 1 if it is larget than mean or viseversa**

# %%
mean = raw_data.rating.mean()
raw_data['target'] = [1 if i>mean else 0 for i in raw_data['rating']]

# %% [markdown]
# **Identify highly correlated features**

# %%
X = raw_data.drop('target',1)
Y = raw_data['target']

# %%
cor_table = raw_data.corrwith(Y).abs()

# %%
df_corr = pd.DataFrame(cor_table)
cols = []
for col, value in df_corr.iterrows():
  if (value > 0.05).bool():
    cols.append(col)

# %%
cols
# Out:
# ['rating',
#  'alcoholic',
#  'bake',
#  'bitters',
#  'bon appétit',
#  'cocktail',
#  'cocktail party',
#  'condiment',
#  'créme de cacao',
#  'drink',
#  'fall',
#  'gin',
#  'harpercollins',
#  'house & garden',
#  'liqueur',
#  'low carb',
#  'non-alcoholic',
#  'peanut free',
#  'roast',
#  'rum',
#  'sauté',
#  'soy free',
#  'spirit',
#  'tree nut free',
#  'winter',
#  'target']

# %% [markdown]
# **Model**

# %%
X = raw_data[cols[:-1]]
X.drop('rating',1,inplace=True)
Y = raw_data['target']

print(X.shape)
print(Y.shape)
# Out:
# (20052, 24)
# (20052,)
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state=0)

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train,y_train)
predicts = svc.predict(x_test)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(svc, x_train, y_train, cv=5)
# Out:
# array([0.80866313, 0.80143392, 0.79831671, 0.80112219, 0.80766833])

# %%
#accuracy

from sklearn.metrics import accuracy_score
accuracy_score(y_test,predicts)
# Out:
# 0.8142607828471703
